# %%
import networkx as nx
import matplotlib.pyplot as plt

# %%
graph = nx.Graph(name='graph1')
graph.add_node(1, data=[{"a": 2}])
graph.add_node(2)
graph.add_edge(1, 2)
graph.add_cycle(n for n in range(6, 10))

# %%
print(nx.info(graph))
nx.draw(graph)
plt.show()
# Out:
# Name: graph1
# Type: Graph
# Number of nodes: 6
# Number of edges: 5
# Average degree:   1.6667
